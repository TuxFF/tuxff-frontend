# %%
import requests
import json

# %%
API_URL = 'https://ms5dlzolh3.execute-api.us-east-2.amazonaws.com/default/player-get-adp'
year = '2024'
player_id = "4de8084d-aa1a-43c7-9676-0def5b39e980"

response = requests.get(f'{API_URL}/{year}/{player_id}')
print(response)
print(response.text)
# Out:
# <Response [404]>
# {"message":"Not Found"}

# %%
response = requests.get('https://ms5dlzolh3.execute-api.us-east-2.amazonaws.com/default/player-get-adp/2024/cb7b1dc6-91ce-47b8-813c-07486371a922')
print(response)
print(response.text)
# Out:
# <Response [200]>
# ...

# %%
response = requests.get('https://12eum45kii.execute-api.us-east-2.amazonaws.com/default/get-player-list')
print(response)
print(response.text)
# Out:
# <Response [200]>
# ...
